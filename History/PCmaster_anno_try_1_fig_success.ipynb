# %%
with open('PCmaster_anno_0_Copy1.py','r') as f:
    exec(f.read())
# Out:
# Memory collecting...
# Memory information:
# Used:
# 294486016
# Total:
# 16806326272
# Used (%):
# 20.5

# %%
filepath = './counts.tsv.gz'

# %%
name_of_what_you_want = PCmaster_anno_0()
name_of_what_you_want.to_annotation_0(filepath = filepath)
# Out:
# scanpy==1.9.2 anndata==0.8.0 umap==0.5.3 numpy==1.21.5 scipy==1.7.3 pandas==1.5.2 scikit-learn==1.2.1 statsmodels==0.13.5 python-igraph==0.10.4 louvain==0.8.0 pynndescent==0.5.8
#
#
# Before filter
#
#
# normalizing counts per cell
#     finished (0:00:00)
# After filter
#
#
# filtered out 2998 genes that are detected in less than 3 cells
# Before filter
#
#
# count     4336.000000
# mean      7103.151983
# std       6376.242052
# min        249.000000
# 25%       3012.000000
# 50%       4970.000000
# 75%       8760.250000
# max      64352.000000
# Name: total_counts, dtype: float64
# count    4336.000000
# mean     2698.808118
# std      1424.931102
# min       215.000000
# 25%      1605.750000
# 50%      2324.000000
# 75%      3431.500000
# max      9922.000000
# Name: n_genes_by_counts, dtype: float64
# count    4336.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: pct_counts_sp, dtype: float64
# ...
